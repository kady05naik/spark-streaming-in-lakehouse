# %% [markdown]
# ### 1. Loading Data

# %%
# %fs ls '/Volumes/cat_spark_streaming/wordcnt/wordcnt/'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/cat_spark_streaming/wordcnt/wordcnt/text_data_1.txt</td><td>text_data_1.txt</td><td>874</td><td>1782826073000</td></tr><tr><td>dbfs:/Volumes/cat_spark_streaming/wordcnt/wordcnt/text_data_2.txt</td><td>text_data_2.txt</td><td>623</td><td>1782826073000</td></tr><tr><td>dbfs:/Volumes/cat_spark_streaming/wordcnt/wordcnt/text_data_3.txt</td><td>text_data_3.txt</td><td>328</td><td>1782826073000</td></tr></tbody></table></div>

# %%
data_path='/Volumes/cat_spark_streaming/wordcnt/wordcnt/'

# %%
lines=spark.read \
    .format('text') \
    .option('multiLine', True) \
    .option('lineSep', '.') \
    .load(vol_location)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-4910558414602803>, line 5
#       1 lines=spark.read \
#       2     .format('text') \
#       3     .option('multiLine', True) \
#       4     .option('lineSep', '.') \
# ----> 5     .load(vol_location)
#
# NameError: name 'vol_location' is not defined

# %%
lines.display()

# %% [markdown]
# ## 2. Processing Data

# %%
from pyspark.sql.functions import explode,split,trim,lower,col,count

# %% [markdown]
# Trim the spaces from both ends for the specified string column

# %%
raw_words=lines.select(explode(split(col('value')," ")).alias('word'))

quality_words=raw_words.select(trim(col('word')).alias('word') )

quality_words=quality_words.select(col('word')) \
                        .where("word is not null") \
                        .where("word rlike '[a-z]'")

# %%
WordCounts=quality_words \
        .groupBy('word') \
        .agg(count(col('word')))

# %%
quality_words.display()
