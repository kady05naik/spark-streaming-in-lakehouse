# %% [markdown]
# ### 1. Loading Data

# %%
data_path='/Volumes/cat_spark_streaming/wordcnt/wordcnt/'

# %%
lines=spark.read \
    .format('text') \
    .option('multiLine', True) \
    .option('lineSep', '.') \
    .load(vol_location)

# %%
lines.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## 2. Processing Data

# %%
from pyspark.sql.functions import explode,split,trim,lower,col

# %% [markdown]
# Trim the spaces from both ends for the specified string column

# %%
raw_words=lines.select(explode(split(col('value'),' ')).alias('word'))
quality_words=raw_words.select(trim(col('word')))

# %%
quality_words.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
quality_words.display()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-4910558414602811>, line 1
# ----> 1 quality_words.display()
#
# File /databricks/python_shell/lib/dbruntime/monkey_patches.py:80, in apply_dataframe_display_patch.<locals>.df_display(df, *args, **kwargs)
#      76 def df_display(df, *args, **kwargs):
#      77     """
#      78     df.display() is an alias for display(df). Run help(display) for more information.
#      79     """
# ---> 80     display(df, *args, **kwargs)
#
# File /databricks/python_shell/lib/dbruntime/display.py:136, in Display.display(self, input, *args, **kwargs)
#     134     pass
#     135 elif self._cf_helper is not None and isinstance(input, ConnectDataFrame):
# --> 136     self.display_connect_table(input, **kwargs)
#     137 elif isinstance(input, ConnectDataFrame):
#     138     if input.isStreaming:
#
# ...
